# %% [markdown]
# <a href="https://colab.research.google.com/github/JetrayProjects/LangChain-LangGraph/blob/main/LangChain101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
